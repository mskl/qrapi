# %%
import pdf2image
from PIL import Image
import time

#DECLARE CONSTANTS
PDF_PATH = "data/example_paylogic.pdf"
OUTPUT_FOLDER = None

# %%
pil_images = pdf2image.convert_from_path(
    PDF_PATH, dpi=200, output_folder=OUTPUT_FOLDER, fmt='jpg', thread_count=1, strict=False
)

# %%
pil_images[0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1654x2339 at 0x109C94FD0>

# %%
from pyzbar.pyzbar import decode

# %%
decoded_list = decode(image=pil_images[0])

# %%
# Out:
# [{'type': 'QRCODE', 'data': '5499944158390'},
#  {'type': 'EAN13', 'data': '5499944158390'}]

# %%
shitty = Image.open("data/shitimg.jpg")

# %%
decode(shitty)
# Out:
# []
